# %%
# =========================================================
# MAIN.IPYNB
# Hazelnut Classification - Experiment Notebook
# =========================================================

# %%
# =========================================================
# IMPORT LIBRARIES
# =========================================================

import sys
import os

sys.path.append(os.path.abspath("../src"))

import pandas as pd
import matplotlib.pyplot as plt

from train import train_model

from dataset import (
    train_loader,
    val_loader,
    test_loader,
    class_names
)

# %%
# =========================================================
# DATASET INFORMATION
# =========================================================

print("=" * 50)

print("Class Names:")

print(class_names)

print("=" * 50)

print(f"Training Batches: {len(train_loader)}")

print(f"Validation Batches: {len(val_loader)}")

print(f"Test Batches: {len(test_loader)}")
# Out:
# ==================================================
# Class Names:
# ['not_ok', 'ok']
# ==================================================
# Training Batches: 11
# Validation Batches: 3
# Test Batches: 3

# %%
# =========================================================
# LOAD ONE BATCH
# =========================================================

images, labels = next(iter(train_loader))

print(images.shape)

print(labels.shape)
# Out:
# torch.Size([32, 3, 128, 128])
# torch.Size([32])

# %%
# =========================================================
# SINGLE CNN EXPERIMENT
# =========================================================

cnn_results = train_model(
    model_type="cnn",
    epochs=1,
    learning_rate=0.001,
    optimizer_name="adam",
    dropout_rate=0.3,
    weight_decay=0.0001
)
# Out:
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/1]
# Train Loss : 0.4285
# Train Acc  : 85.97%
# Val Loss   : 0.4933
# Val Acc    : 80.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-1.pth
#
# ============================================================
# Training Finished Successfully
# ============================================================

# %%
# =========================================================
# SINGLE ANN EXPERIMENT
# =========================================================

ann_results = train_model(
    model_type="ann",
    epochs=10,
    learning_rate=0.001,
    optimizer_name="adam",
    dropout_rate=0.3,
    weight_decay=0.0001
)
# Out:
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 3.3691
# Train Acc  : 74.63%
# Val Loss   : 2.0890
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 2.1668
# Train Acc  : 76.72%
# Val Loss   : 2.3417
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 1.3513
# Train Acc  : 76.42%
# Val Loss   : 0.8725
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.8853
# Train Acc  : 74.93%
# Val Loss   : 0.5077
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.5689
# Train Acc  : 84.48%
# Val Loss   : 0.5122
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.4584
# Train Acc  : 84.78%
# Val Loss   : 0.4506
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.4964
# Train Acc  : 84.48%
# Val Loss   : 0.4268
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.4308
# Train Acc  : 85.97%
# Val Loss   : 0.4244
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.4150
# Train Acc  : 86.27%
# Val Loss   : 0.4289
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.4411
# Train Acc  : 85.97%
# Val Loss   : 0.4428
# Val Acc    : 80.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: models\ann_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-10.pth
#
# ============================================================
# Training Finished Successfully
# ============================================================

# %% [markdown]
# ### learning rate tuning

# %%
# =========================================================
# LEARNING RATE TUNING
# =========================================================

learning_rates = [0.1, 0.01, 0.001]

for lr in learning_rates:

    print(f"\nTraining with Learning Rate = {lr}")

    train_model(
        model_type="cnn",
        epochs=10,
        learning_rate=lr,
        optimizer_name="adam",
        dropout_rate=0.3,
        weight_decay=0.0001
    )
# Out:
# Training with Learning Rate = 0.1
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 1857.7784
# Train Acc  : 69.25%
# Val Loss   : 0.4753
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 124.0524
# Train Acc  : 82.99%
# Val Loss   : 1341.8640
# Val Acc    : 20.00%
# Possible Overfitting Detected
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 135.3406
# Train Acc  : 80.90%
# Val Loss   : 0.4881
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.4740
# Train Acc  : 85.97%
# Val Loss   : 0.4364
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.4511
# Train Acc  : 86.27%
# Val Loss   : 0.4348
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.4527
# Train Acc  : 86.27%
# Val Loss   : 0.4492
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.4076
# Train Acc  : 86.27%
# Val Loss   : 0.4349
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.4375
# Train Acc  : 86.27%
# Val Loss   : 0.4343
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.4168
# Train Acc  : 86.27%
# Val Loss   : 0.4356
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.3944
# Train Acc  : 86.27%
# Val Loss   : 0.4366
# Val Acc    : 80.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.1_drop-0.3_wd-0.0001_epoch-10.pth
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Learning Rate = 0.01
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 7.4746
# Train Acc  : 74.63%
# Val Loss   : 0.9516
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.6134
# Train Acc  : 87.76%
# Val Loss   : 0.5736
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.4212
# Train Acc  : 89.55%
# Val Loss   : 0.4160
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3453
# Train Acc  : 90.45%
# Val Loss   : 0.7152
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3304
# Train Acc  : 90.45%
# Val Loss   : 0.4361
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3267
# Train Acc  : 90.15%
# Val Loss   : 0.5922
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.3487
# Train Acc  : 90.45%
# Val Loss   : 0.4443
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.3095
# Train Acc  : 90.75%
# Val Loss   : 0.3693
# Val Acc    : 85.33%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.2647
# Train Acc  : 91.34%
# Val Loss   : 0.3585
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.2380
# Train Acc  : 92.54%
# Val Loss   : 0.3047
# Val Acc    : 86.67%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.01_drop-0.3_wd-0.0001_epoch-10.pth
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Learning Rate = 0.001
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.5073
# Train Acc  : 86.27%
# Val Loss   : 0.4569
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.4360
# Train Acc  : 86.27%
# Val Loss   : 0.4519
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.4005
# Train Acc  : 86.27%
# Val Loss   : 0.4303
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3641
# Train Acc  : 86.57%
# Val Loss   : 0.4082
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3484
# Train Acc  : 87.76%
# Val Loss   : 0.4026
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3392
# Train Acc  : 88.66%
# Val Loss   : 0.4268
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.3170
# Train Acc  : 89.25%
# Val Loss   : 0.3858
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.2954
# Train Acc  : 90.15%
# Val Loss   : 0.3892
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.2978
# Train Acc  : 90.75%
# Val Loss   : 0.3861
# Val Acc    : 82.67%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.3066
# Train Acc  : 89.85%
# Val Loss   : 0.3967
# Val Acc    : 84.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-10.pth
#
# ============================================================
# Training Finished Successfully
# ============================================================

# %% [markdown]
# ### Dropout tuning

# %%
# =========================================================
# DROPOUT TUNING
# =========================================================

dropout_rates = [0.2, 0.3, 0.5]

for dropout in dropout_rates:

    print(f"\nTraining with Dropout = {dropout}")

    train_model(
        model_type="cnn",
        epochs=10,
        learning_rate=0.001,
        optimizer_name="adam",
        dropout_rate=dropout,
        weight_decay=0.0001
    )
# Out:
# Training with Dropout = 0.2
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.4599
# Train Acc  : 86.27%
# Val Loss   : 0.4818
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.3982
# Train Acc  : 86.27%
# Val Loss   : 0.4133
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.3741
# Train Acc  : 86.27%
# Val Loss   : 0.4133
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3382
# Train Acc  : 88.06%
# Val Loss   : 0.4215
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3252
# Train Acc  : 89.85%
# Val Loss   : 0.3875
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3048
# Train Acc  : 89.55%
# Val Loss   : 0.3871
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.2823
# Train Acc  : 89.85%
# Val Loss   : 0.4486
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.2944
# Train Acc  : 90.45%
# Val Loss   : 0.3573
# Val Acc    : 82.67%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.2706
# Train Acc  : 90.75%
# Val Loss   : 0.3941
# Val Acc    : 86.67%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.2628
# Train Acc  : 91.94%
# Val Loss   : 0.3867
# Val Acc    : 85.33%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.2_wd-0.0001_epoch-10.pth
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Dropout = 0.3
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.5440
# Train Acc  : 82.09%
# Val Loss   : 0.4953
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.4282
# Train Acc  : 86.27%
# Val Loss   : 0.4314
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.3896
# Train Acc  : 86.27%
# Val Loss   : 0.4144
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3394
# Train Acc  : 88.66%
# Val Loss   : 0.4207
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3496
# Train Acc  : 89.55%
# Val Loss   : 0.4316
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3322
# Train Acc  : 89.25%
# Val Loss   : 0.3805
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.2920
# Train Acc  : 89.55%
# Val Loss   : 0.3913
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.2737
# Train Acc  : 89.85%
# Val Loss   : 0.4604
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.2948
# Train Acc  : 90.15%
# Val Loss   : 0.4006
# Val Acc    : 85.33%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.2428
# Train Acc  : 91.04%
# Val Loss   : 0.5260
# Val Acc    : 82.67%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-10.pth
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Dropout = 0.5
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.5593
# Train Acc  : 79.10%
# Val Loss   : 0.4284
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.4026
# Train Acc  : 86.27%
# Val Loss   : 0.4292
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.4107
# Train Acc  : 86.27%
# Val Loss   : 0.4146
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3935
# Train Acc  : 85.97%
# Val Loss   : 0.4072
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3663
# Train Acc  : 87.46%
# Val Loss   : 0.4073
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3429
# Train Acc  : 89.25%
# Val Loss   : 0.3916
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.3114
# Train Acc  : 89.85%
# Val Loss   : 0.4238
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.3145
# Train Acc  : 89.25%
# Val Loss   : 0.4242
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.3349
# Train Acc  : 89.55%
# Val Loss   : 0.4462
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.3331
# Train Acc  : 89.85%
# Val Loss   : 0.4387
# Val Acc    : 81.33%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.5_wd-0.0001_epoch-10.pth
#
# ============================================================
# Training Finished Successfully
# ============================================================

# %% [markdown]
# ### WEIGHT DECAY tuning

# %%
# =========================================================
# WEIGHT DECAY TUNING
# =========================================================

weight_decays = [0.0, 0.0001, 0.001]

for wd in weight_decays:

    print(f"\nTraining with Weight Decay = {wd}")

    train_model(
        model_type="cnn",
        epochs=10,
        learning_rate=0.001,
        optimizer_name="adam",
        dropout_rate=0.3,
        weight_decay=wd
    )
# Out:
# Training with Weight Decay = 0.0
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.8262
# Train Acc  : 80.00%
# Val Loss   : 0.4950
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.4505
# Train Acc  : 86.27%
# Val Loss   : 0.4380
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.3996
# Train Acc  : 86.27%
# Val Loss   : 0.4210
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3700
# Train Acc  : 86.27%
# Val Loss   : 0.4096
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3253
# Train Acc  : 89.25%
# Val Loss   : 0.4134
# Val Acc    : 82.67%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3034
# Train Acc  : 88.66%
# Val Loss   : 0.4079
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.3036
# Train Acc  : 90.15%
# Val Loss   : 0.4440
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.3041
# Train Acc  : 90.15%
# Val Loss   : 0.4414
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.2470
# Train Acc  : 91.94%
# Val Loss   : 0.4276
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.2318
# Train Acc  : 91.64%
# Val Loss   : 0.5155
# Val Acc    : 84.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0_epoch-10.pth
#
# Close experiment_results.csv before training.
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Weight Decay = 0.0001
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.4609
# Train Acc  : 82.99%
# Val Loss   : 0.4427
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.4192
# Train Acc  : 86.27%
# Val Loss   : 0.4153
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.3578
# Train Acc  : 87.16%
# Val Loss   : 0.4396
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3300
# Train Acc  : 89.25%
# Val Loss   : 0.4121
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.2997
# Train Acc  : 89.25%
# Val Loss   : 0.4148
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.2826
# Train Acc  : 90.15%
# Val Loss   : 0.4963
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.3168
# Train Acc  : 89.85%
# Val Loss   : 0.4184
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.2765
# Train Acc  : 90.45%
# Val Loss   : 0.4478
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.2792
# Train Acc  : 90.75%
# Val Loss   : 0.4211
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.2206
# Train Acc  : 91.94%
# Val Loss   : 0.5224
# Val Acc    : 84.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-10.pth
#
# Close experiment_results.csv before training.
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Weight Decay = 0.001
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.4930
# Train Acc  : 85.67%
# Val Loss   : 0.4395
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.4028
# Train Acc  : 86.27%
# Val Loss   : 0.4205
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.3738
# Train Acc  : 86.57%
# Val Loss   : 0.3997
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3558
# Train Acc  : 88.66%
# Val Loss   : 0.3854
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3098
# Train Acc  : 89.85%
# Val Loss   : 0.3812
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3027
# Train Acc  : 89.55%
# Val Loss   : 0.3868
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.2955
# Train Acc  : 89.85%
# Val Loss   : 0.4319
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.2567
# Train Acc  : 90.45%
# Val Loss   : 0.5073
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.3297
# Train Acc  : 91.04%
# Val Loss   : 0.4361
# Val Acc    : 85.33%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.3061
# Train Acc  : 90.75%
# Val Loss   : 0.4574
# Val Acc    : 82.67%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.001_epoch-10.pth
#
# Close experiment_results.csv before training.
#
# ============================================================
# Training Finished Successfully
# ============================================================

# %% [markdown]
# ### EPOCH tuning

# %%
# =========================================================
# EPOCH TUNING
# =========================================================

epochs_list = [5, 10, 15]

for epoch in epochs_list:

    print(f"\nTraining with Epochs = {epoch}")

    train_model(
        model_type="cnn",
        epochs=epoch,
        learning_rate=0.001,
        optimizer_name="adam",
        dropout_rate=0.3,
        weight_decay=0.0001
    )
# Out:
# Training with Epochs = 5
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/5]
# Train Loss : 0.4847
# Train Acc  : 81.79%
# Val Loss   : 0.4333
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/5]
# Train Loss : 0.3849
# Train Acc  : 86.27%
# Val Loss   : 0.4392
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [3/5]
# Train Loss : 0.3793
# Train Acc  : 86.57%
# Val Loss   : 0.3881
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/5]
# Train Loss : 0.3560
# Train Acc  : 88.36%
# Val Loss   : 0.3882
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/5]
# Train Loss : 0.3319
# Train Acc  : 88.96%
# Val Loss   : 0.3852
# Val Acc    : 81.33%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-5.pth
#
# Close experiment_results.csv before training.
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Epochs = 10
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.4673
# Train Acc  : 79.40%
# Val Loss   : 0.4221
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.4099
# Train Acc  : 86.27%
# Val Loss   : 0.4392
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.4041
# Train Acc  : 86.27%
# Val Loss   : 0.4016
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3272
# Train Acc  : 87.76%
# Val Loss   : 0.5853
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3721
# Train Acc  : 89.25%
# Val Loss   : 0.4271
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3091
# Train Acc  : 89.55%
# Val Loss   : 0.3915
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.3058
# Train Acc  : 89.85%
# Val Loss   : 0.3920
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.3126
# Train Acc  : 90.15%
# Val Loss   : 0.3906
# Val Acc    : 85.33%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.3104
# Train Acc  : 89.85%
# Val Loss   : 0.3863
# Val Acc    : 82.67%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.2603
# Train Acc  : 90.45%
# Val Loss   : 0.4095
# Val Acc    : 84.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-10.pth
#
# Close experiment_results.csv before training.
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Epochs = 15
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/15]
# Train Loss : 0.5599
# Train Acc  : 79.40%
# Val Loss   : 0.4350
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/15]
# Train Loss : 0.3925
# Train Acc  : 86.27%
# Val Loss   : 0.4326
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/15]
# Train Loss : 0.3983
# Train Acc  : 86.27%
# Val Loss   : 0.4324
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/15]
# Train Loss : 0.3555
# Train Acc  : 87.16%
# Val Loss   : 0.4010
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/15]
# Train Loss : 0.3221
# Train Acc  : 89.25%
# Val Loss   : 0.3968
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [6/15]
# Train Loss : 0.2984
# Train Acc  : 89.55%
# Val Loss   : 0.3725
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/15]
# Train Loss : 0.3026
# Train Acc  : 90.15%
# Val Loss   : 0.4255
# Val Acc    : 85.33%
# ============================================================
# ============================================================
# Epoch [8/15]
# Train Loss : 0.2615
# Train Acc  : 90.45%
# Val Loss   : 0.4460
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [9/15]
# Train Loss : 0.2573
# Train Acc  : 90.45%
# Val Loss   : 0.4207
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [10/15]
# Train Loss : 0.2322
# Train Acc  : 92.24%
# Val Loss   : 0.4427
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [11/15]
# Train Loss : 0.2224
# Train Acc  : 90.75%
# Val Loss   : 0.4598
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [12/15]
# Train Loss : 0.2108
# Train Acc  : 91.94%
# Val Loss   : 0.4462
# Val Acc    : 86.67%
# ============================================================
# ============================================================
# Epoch [13/15]
# Train Loss : 0.1776
# Train Acc  : 93.73%
# Val Loss   : 0.4647
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [14/15]
# Train Loss : 0.1887
# Train Acc  : 93.43%
# Val Loss   : 0.4827
# Val Acc    : 88.00%
# ============================================================
# ============================================================
# Epoch [15/15]
# Train Loss : 0.2021
# Train Acc  : 92.84%
# Val Loss   : 0.5225
# Val Acc    : 84.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-15.pth
#
# Close experiment_results.csv before training.
#
# ============================================================
# Training Finished Successfully
# ============================================================

# %% [markdown]
# ### OPTIMIZER tuning

# %%
# =========================================================
# OPTIMIZER TUNING
# =========================================================

optimizers = ["adam", "sgd"]

for optimizer in optimizers:

    print(f"\nTraining with Optimizer = {optimizer}")

    train_model(
        model_type="cnn",
        epochs=10,
        learning_rate=0.001,
        optimizer_name=optimizer,
        dropout_rate=0.3,
        weight_decay=0.0001
    )
# Out:
# Training with Optimizer = adam
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.5274
# Train Acc  : 77.91%
# Val Loss   : 0.4407
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.3993
# Train Acc  : 86.27%
# Val Loss   : 0.4174
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.3476
# Train Acc  : 87.46%
# Val Loss   : 0.3953
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.3304
# Train Acc  : 89.55%
# Val Loss   : 0.3825
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3074
# Train Acc  : 89.25%
# Val Loss   : 0.3953
# Val Acc    : 82.67%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.2893
# Train Acc  : 90.15%
# Val Loss   : 0.4512
# Val Acc    : 81.33%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.2686
# Train Acc  : 91.34%
# Val Loss   : 0.4436
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.2830
# Train Acc  : 90.45%
# Val Loss   : 0.4181
# Val Acc    : 85.33%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.2431
# Train Acc  : 91.34%
# Val Loss   : 0.4202
# Val Acc    : 84.00%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.2271
# Train Acc  : 91.64%
# Val Loss   : 0.4784
# Val Acc    : 84.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-10.pth
#
# Close experiment_results.csv before training.
#
# ============================================================
# Training Finished Successfully
# ============================================================
#
# Training with Optimizer = sgd
#
# ============================================================
# Using Device: cpu
# ============================================================
#
# Starting Training...
#
# ============================================================
# Epoch [1/10]
# Train Loss : 0.5900
# Train Acc  : 74.63%
# Val Loss   : 0.4595
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [2/10]
# Train Loss : 0.4401
# Train Acc  : 86.27%
# Val Loss   : 0.4636
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [3/10]
# Train Loss : 0.4028
# Train Acc  : 86.27%
# Val Loss   : 0.4275
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [4/10]
# Train Loss : 0.4132
# Train Acc  : 86.27%
# Val Loss   : 0.4286
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [5/10]
# Train Loss : 0.3922
# Train Acc  : 86.27%
# Val Loss   : 0.4276
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [6/10]
# Train Loss : 0.3950
# Train Acc  : 86.27%
# Val Loss   : 0.4310
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [7/10]
# Train Loss : 0.3972
# Train Acc  : 86.27%
# Val Loss   : 0.4287
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [8/10]
# Train Loss : 0.4121
# Train Acc  : 86.27%
# Val Loss   : 0.4283
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [9/10]
# Train Loss : 0.3983
# Train Acc  : 86.27%
# Val Loss   : 0.4277
# Val Acc    : 80.00%
# ============================================================
# ============================================================
# Epoch [10/10]
# Train Loss : 0.3947
# Train Acc  : 86.27%
# Val Loss   : 0.4283
# Val Acc    : 80.00%
# ============================================================
#
# Model Saved Successfully
# Saved Path: s:\albstadt sigmaringen university\digital technology and management\hazelnut-classification\models\cnn_opt-sgd_lr-0.001_drop-0.3_wd-0.0001_epoch-10.pth
#
# Close experiment_results.csv before training.
#
# ============================================================
# Training Finished Successfully
# ============================================================

# %% [markdown]
# ## testing Phase

# %%
import torch
import torch.nn as nn

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from model_ANN import ANNModel
from model_CNN import CNNModel

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Using Device:", device)
# Out:
# Using Device: cpu

# %%
model = CNNModel().to(device)

model_path = "../models/cnn_opt-adam_lr-0.001_drop-0.3_wd-0.0001_epoch-10.pth"

model.load_state_dict(
    torch.load(model_path, map_location=device)
)

model.eval()

print("CNN Model Loaded Successfully")
# Out:
# CNN Model Loaded Successfully

# %%
all_preds = []
all_labels = []

correct = 0
total = 0

# Disable gradient calculation
with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)

        # Get predicted class
        _, preds = torch.max(outputs, 1)

        # Store predictions
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        # Accuracy calculation
        correct += (preds == labels).sum().item()

        total += labels.size(0)

# Final accuracy
accuracy = 100 * correct / total

print(f"\nTest Accuracy: {accuracy:.2f}%")
# Out:
# Test Accuracy: 90.79%

# %%
print("\nClassification Report:\n")

print(classification_report(
    all_labels,
    all_preds,
    target_names=class_names
))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       not_ok       0.67      0.44      0.53         9
#           ok       0.93      0.97      0.95        67
#
#     accuracy                           0.91        76
#    macro avg       0.80      0.71      0.74        76
# weighted avg       0.90      0.91      0.90        76

# %%
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# %%
images, labels = next(iter(test_loader))

images = images.to(device)

with torch.no_grad():

    outputs = model(images)

    _, preds = torch.max(outputs, 1)

# Move images back to CPU
images = images.cpu()

plt.figure(figsize=(12, 8))

for i in range(9):

    plt.subplot(3, 3, i + 1)

    img = images[i].permute(1, 2, 0).numpy()

    # Unnormalize image
    img = (img * 0.5) + 0.5

    plt.imshow(img)

    true_label = class_names[labels[i]]
    pred_label = class_names[preds[i]]

    plt.title(f"True: {true_label}\nPred: {pred_label}")

    plt.axis("off")

plt.tight_layout()

plt.show()
